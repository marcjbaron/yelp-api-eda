# %%
# %load_ext sql

# %%
# %sql sqlite:///poi.db

# %%
# %sql SELECT * FROM yelp_sql
# Out:
#  * sqlite:///poi.db
# Done.
# [('venue_1', 'Insomnia Restaurant & Lounge', 4.0, 'lounges', 'Lounges', '563 Bloor Street W', '', '', 'Toronto', 'M5S 1Y6', 'CA', 'ON', '563 Bloor Street W', 'Bloor Street W'),
#  ('venue_2', 'The Stockyards', 4.0, 'tradamerican', 'American (Traditional)', '699 St. Clair Avenue W', '', '', 'Toronto', 'M6C 1B2', 'CA', 'ON', '699 St. Clair Avenue W', 'St. Clair Avenue W'),
#  ('venue_3', "Emma's Country Kitchen", 4.0, 'breakfast_brunch', 'Breakfast & Brunch', '810 Saint Clair Avenue W', '', '', 'Toronto', 'M6C 1B6', 'CA', 'ON', '810 Saint Clair Avenue W', 'Saint Clair Avenue W'),
#  ('venue_4', 'Bakerbots Baking', 4.0, 'desserts', 'Desserts', '205 Delaware Avenue', '', '', 'Toronto', 'M6H 2T4', 'CA', 'ON', '205 Delaware Avenue', 'Delaware Avenue'),
#  ('venue_5', 'Buk Chang Dong Soon Tofu', 4.0, 'korean', 'Korean', '691 Bloor Street W', '', '', 'Toronto', 'M6G 1L3', 'CA', 'ON', '691 Bloor Street W', 'Bloor Street W'),
# ...
